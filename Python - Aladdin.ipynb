# %% [markdown]
# # Aladdin Game!
#
# ### Story
#
# Once upon a time in the land of Agrabah, there lived a poor but good-hearted boy named Aladdin. One day he rescued Princess Jasmine, who posed as her maid, from a problem, and Aladdin fell in love with the princess. Jafar, the advisor to the sultan of Agrabah, plans to overthrow the sultan and thus have complete power and for this he will look for the magic lamp which grants 3 wishes to whoever possesses it. Aladdin discovers that the girl he rescued was the princess of Agrabah and to make her fall in love, with the help of the lamp and the Genie he becomes Prince Ali, however, he was exposed bu Jafar who snatched the lamp from him and sent it to a cave.
#
# ### Game
# Aladdin is trapped in the cave trying to get to the cage where the magic lamp is. The cage opens with 3 keys, each key is located in 3 different places that lead to the cage. To get a key and got to the next place Aladdin will have to answer each question correctly.
# Help Aladdin to recover the magic lamp to send Jafar away and marry Princess Jasmine.
#
# ### Objective
# Get the 3 keys to open the cage where the magic lamp is.
#
# ### Reference
# Disney (2019). Aladdin 2019 film.
# https://disney.fandom.com/wiki/Aladdin_(2019_film)

# %%
## Input for user name
user_name  = input(prompt = f"""

                     ..    d$P              $$      `$b
                    z$"   $$F               4$$      $$L
                    $$   4$$                 $$.     4$$    ,z$P
                    $$   $$'                 $$F      $$   $$$P
                   $$$   $$                  $$f      $$   ""`
                  $'$$; 4$F      .,_         $$'      $$
                .$' ?$L 4$'   .d$" `?    zee $$   ,ec $F  d$F z$$   ,ce,.
              .d$ee. $$ 4$'  d$"   z$  $$"  .$f.d$"  4$  4$$ 4$$P z$P?$$$
             d$" "?$$d$,`$  $$F   z$f,$$    $$.$$    $P  $$% $$$4$"   4$$
.$"%.     ,p$"        $$ $ J$$  z$$$ $$"  .$$ $$"  .$$C 4$P  $$$"     $$f
`$.     ,d$b****q,     $.$ $$$$$P $$.$$b.$P4$ $$L.$P4$F $P  4$P     .$$"
 `?$$g$P"        "     `b' `??"   "?"^?F"   $$`?PF"  $$ "   P'     eF


                    Welcome to the magical world of Aladdin! 
    
    Aladdin is trapped in a cave, your goal is to help him reach the cage
    and retrieve the magic lamp
                
    What's your name? """)

## Page break 
user_name = user_name.capitalize()

## Answer for user name

answer_1 = input (prompt = f"""
    Welcome {user_name}!\n
    To achieve the goal you will have to get the 3 keys by correctly answering
    the questions of each place\n
    Press enter to start\n""")

## Declare variables

## Defining win and fail function

def win_game():
    print("Congratulations! You won the game and helped Aladdin to get the magic lamp!")
    
def fail():
    print("Sorry you lost the game. You can try again!")
    
## Constructing place_1 and calling it to start the game
    
def place_1():

    question_1= ["Place_1:\n\nWhat is the name of the Aladdin's adventure friend?",
                 "Abi", "Abu", "Babi", "Babu"]
    
    ## Give 3 attempts for every place

    attempts = 3
    
    print(question_1[0])
    for choice in range(1,5):
        print(f"{choice}. {question_1[choice]}")

    while attempts > 0:
        
        user_input = input(prompt= "> ")

        if user_input.lower() == "abi":
            ## If user has 1 mistake they'll lose 1 attempt
            attempts = attempts - 1
            ## If there are no more attempts, then call fail function
            if attempts == 0:
                fail()
            ## Otherwise the user will continue the game
            print(f"Sorry! Wrong answer. You have {attempts} attempts left\n")

        elif user_input.lower() == "abu" or user_input.lower() == "2":
            print("Yes! You are right, you have got 1 key\n")
            place_2()
            attempts = attempts - 3

        elif user_input.lower() == "babi":
            attempts = attempts - 1
            if attempts == 0:
                fail()
            print(f"Sorry! Wrong answer. You have {attempts} attempts left\n")

        elif user_input.lower() == "babu":
            attempts = attempts - 1
            if attempts == 0:
                fail()
            print(f"Sorry! Wrong answer. You have {attempts} attempts left\n")

        else:
            attempts = attempts - 1
            if attempts == 0:
                fail()
            print(f"Sorry, I don't understand you. You have {attempts} attempts left\n")


## Defining place_2 with while loop
            
def place_2():
    
    question_2= ["Place_2:\n\nWho plays the Genie of the lamp?",
                 "Mena Massoud", "Will Smith", "Dwayne Johnson", "Jaden Smith"]
    
    ## Give 3 attempts for every place

    attempts = 3
    
    print(question_2[0])
    for choice in range(1,5):
        print(f"{choice}. {question_2[choice]}")

    while attempts > 0:
        
        user_input = input(prompt= ">")

        if user_input.lower() == "mena massoud":
            ## If user has 1 mistake they'll lose 1 attempt
            attempts = attempts - 1
            ## If there are no more attempts, then call fail function
            if attempts == 0:
                fail()
            ## Otherwise the user will continue the game    
            print(f"Sorry! Wrong answer. You have {attempts} attempts left\n")

        elif user_input.lower() == "will smith" or user_input.lower() == "2":
            print("Yes! You are right, now you have 2 keys\n")
            place_3()
            attempts = attempts - 3

        elif user_input.lower() == "dwayne johnson":
            attempts = attempts - 1
            if attempts == 0:
                fail()
            print(f"Sorry! Wrong answer. You have {attempts} attempts left\n")

        elif user_input.lower() == "jaden smith":
            attempts = attempts - 1
            if attempts == 0:
                fail()
            print(f"Sorry! Wrong answer. You have {attempts} attempts left\n")

        else:
            attempts = attempts - 1
            if attempts == 0:
                fail()
            print(f"Sorry, I don't understand you. You have {attempts} attempts left\n")
            

## Defining place_3 with while loop

def place_3():

    question_3= ["Place_3:\n\nWhat is the Genie's most desired wish?",
                 "Become a prince", "Marry Dalia", "Get freedom", "Gain power"]
    
    ## Give 3 attempts for every place
    
    attempts = 3
    
    print(question_3[0])
    for choice in range(1,5):
        print(f"{choice}. {question_3[choice]}")

    while attempts > 0:
        user_input = input(prompt= "< ")

        if user_input.lower() == "become a prince":
            ## If user has 1 mistake they'll lose 1 attempt
            attempts = attempts - 1
            ## If there are no more attempts, then call fail function
            if attempts == 0:
                fail()
            ## Otherwise the user will continue the game
            else:
                print(f"Sorry! Wrong answer. You have {attempts} attempts left\n")
           
        elif user_input.lower() == "marry dalia":
            attempts = attempts - 1
            if attempts == 0:
                fail()
            else:
                print(f"Sorry! Wrong answer. You have {attempts} attempts left\n")
            
        ## If user answer correctly call win function and quit loop
        elif user_input.lower() == "get freedom" or user_input.lower() == "3":
            print("Yes! You are right, you have 3 keys\n\n")
            win_game()
            ## Giving attempt = 0 to quit the loop
            attempts = attempts - 3

        elif user_input.lower() == "gain power":
            attempts = attempts - 1
            if attempts == 0:
                fail()
            else:
                print(f"Sorry! Wrong answer. You have {attempts} attempts left\n")

        else:
            attempts = attempts - 1
            if attempts == 0:
                fail()
            else:
                print(f"Sorry, I don't understand you. You have {attempts} attempts left\n")
                
            
place_1()
